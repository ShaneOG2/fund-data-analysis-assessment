# %% [markdown]
# <h3 style="color: #001a79;">Exercise 1</h3>
#
# <hr style="border-top: 1px solid #001a79;" />
#
# Adapt the code from 01-information Jupyer Notebook in notes to generate a 1000 character long string with weights based on the previous two characters.
#
# Firstly, we start by getting the Alice in Wonderland book and storing off www.gutenberg.org, then store it as one big string called **sbook**.

# %%
# Make HTTP requests for internet reqources.
import urllib.request

# For doing (pseudo-)random things in Python.
import random

# The URL of a text version of Alice in Wonderland.
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# Get the book.
book = list(urllib.request.urlopen(book_url))

# Decode the lines and strip line endings.
book = [line.decode('utf-8-sig').strip() for line in book]

# Get the whole book in one big string.
sbook = ''.join(book[26:]).lower()

# %% [markdown]
# Secondly, we create a dictionary with the weighting system.
#
# The first key is each of the two previous characters possibilites (e.g. "aa", "ba", "ca",............,"y ", "z ", "  ") and it's value is another dictionary. The key of this dictionary is chars (each letter of the alphabet plus space) and its values are the weights of the key.

# %%
# All letters and a space.
chars = 'abcdefghijklmnopqrstuvwxyz '

# Create the weights.
threeghts = {(x + y): {z: sbook.count(x + y + z) for z in chars} for y in chars for x in chars}
threeghts
# Out:
# {'aa': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ba': {'a': 0,
#   'b': 14,
#   'c': 40,
#   'd': 2,
#   'e': 0,
#   'f': 0,
#   'g': 1,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 1,
#   'l': 2,
#   'm': 0,
#   'n': 5,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 6,
#   's': 2,
#   't': 8,
#   'u': 0,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ca': {'a': 0,
#   'b': 3,
#   'c': 1,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 6,
#   'l': 36,
#   'm': 43,
#   'n': 84,
#   'o': 0,
#   'p': 9,
#   'q': 0,
#   'r': 28,
#   's': 7,
#   't': 101,
#   'u': 35,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'da': {'a': 0,
#   'b': 3,
#   'c': 0,
#   'd': 1,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 3,
#   'j': 0,
#   'k': 0,
#   'l': 9,
#   'm': 7,
#   'n': 20,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 11,
#   's': 1,
#   't': 33,
#   'u': 1,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 43,
#   'z': 0,
#   ' ': 3},
#  'ea': {'a': 0,
#   'b': 1,
#   'c': 31,
#   'd': 137,
#   'e': 0,
#   'f': 0,
#   'g': 18,
#   'h': 1,
#   'i': 0,
#   'j': 0,
#   'k': 29,
#   'l': 38,
#   'm': 18,
#   'n': 41,
#   'o': 1,
#   'p': 5,
#   'q': 0,
#   'r': 213,
#   's': 77,
#   't': 129,
#   'u': 21,
#   'v': 18,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 23},
#  'fa': {'a': 0,
#   'b': 0,
#   'c': 29,
#   'd': 1,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 8,
#   'j': 0,
#   'k': 0,
#   'l': 14,
#   'm': 2,
#   'n': 24,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 16,
#   's': 9,
#   't': 8,
#   'u': 1,
#   'v': 2,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 2},
#  'ga': {'a': 0,
#   'b': 1,
#   'c': 1,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 1,
#   'h': 0,
#   'i': 94,
#   'j': 0,
#   'k': 0,
#   'l': 6,
#   'm': 14,
#   'n': 66,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 30,
#   's': 2,
#   't': 1,
#   'u': 0,
#   'v': 15,
#   'w': 0,
#   'x': 0,
#   'y': 1,
#   'z': 1,
#   ' ': 1},
#  'ha': {'a': 0,
#   'b': 1,
#   'c': 2,
#   'd': 187,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 10,
#   'j': 0,
#   'k': 5,
#   'l': 60,
#   'm': 2,
#   'n': 117,
#   'o': 0,
#   'p': 69,
#   'q': 0,
#   'r': 83,
#   's': 29,
#   't': 540,
#   'u': 0,
#   'v': 104,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 1},
#  'ia': {'a': 0,
#   'b': 4,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 20,
#   'm': 9,
#   'n': 5,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 15,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 2},
#  'ja': {'a': 0,
#   'b': 0,
#   'c': 1,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 2,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 3,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ka': {'a': 0,
#   'b': 5,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 5,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 1,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'la': {'a': 0,
#   'b': 7,
#   'c': 21,
#   'd': 18,
#   'e': 0,
#   'f': 1,
#   'g': 0,
#   'h': 0,
#   'i': 30,
#   'j': 0,
#   'k': 1,
#   'l': 1,
#   'm': 12,
#   'n': 26,
#   'o': 0,
#   'p': 5,
#   'q': 0,
#   'r': 89,
#   's': 60,
#   't': 37,
#   'u': 7,
#   'v': 1,
#   'w': 20,
#   'x': 0,
#   'y': 26,
#   'z': 2,
#   ' ': 2},
#  'ma': {'a': 0,
#   'b': 4,
#   'c': 2,
#   'd': 46,
#   'e': 0,
#   'f': 0,
#   'g': 12,
#   'h': 0,
#   'i': 15,
#   'j': 12,
#   'k': 50,
#   'l': 25,
#   'm': 0,
#   'n': 55,
#   'o': 0,
#   'p': 1,
#   'q': 0,
#   'r': 94,
#   's': 5,
#   't': 27,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 1,
#   'y': 31,
#   'z': 0,
#   ' ': 2},
#  'na': {'a': 0,
#   'b': 4,
#   'c': 2,
#   'd': 0,
#   'e': 0,
#   'f': 1,
#   'g': 15,
#   'h': 14,
#   'i': 3,
#   'j': 0,
#   'k': 0,
#   'l': 13,
#   'm': 17,
#   'n': 6,
#   'o': 0,
#   'p': 1,
#   'q': 0,
#   'r': 7,
#   's': 1,
#   't': 44,
#   'u': 0,
#   'v': 9,
#   'w': 0,
#   'x': 0,
#   'y': 1,
#   'z': 0,
#   ' ': 3},
#  'oa': {'a': 0,
#   'b': 0,
#   'c': 1,
#   'd': 1,
#   'e': 0,
#   'f': 0,
#   'g': 1,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 2,
#   'm': 0,
#   'n': 4,
#   'o': 0,
#   'p': 1,
#   'q': 0,
#   'r': 8,
#   's': 3,
#   't': 4,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 2,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'pa': {'a': 0,
#   'b': 0,
#   'c': 6,
#   'd': 1,
#   'e': 0,
#   'f': 0,
#   'g': 3,
#   'h': 0,
#   'i': 16,
#   'j': 0,
#   'k': 0,
#   'l': 4,
#   'm': 0,
#   'n': 10,
#   'o': 0,
#   'p': 7,
#   'q': 0,
#   'r': 56,
#   's': 18,
#   't': 20,
#   'u': 3,
#   'v': 0,
#   'w': 8,
#   'x': 0,
#   'y': 7,
#   'z': 0,
#   ' ': 0},
#  'qa': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ra': {'a': 0,
#   'b': 62,
#   'c': 13,
#   'd': 16,
#   'e': 0,
#   'f': 0,
#   'g': 22,
#   'h': 0,
#   'i': 22,
#   'j': 0,
#   'k': 0,
#   'l': 37,
#   'm': 5,
#   'n': 46,
#   'o': 2,
#   'p': 21,
#   'q': 0,
#   'r': 14,
#   's': 14,
#   't': 50,
#   'u': 0,
#   'v': 13,
#   'w': 15,
#   'x': 0,
#   'y': 5,
#   'z': 2,
#   ' ': 1},
#  'sa': {'a': 0,
#   'b': 2,
#   'c': 0,
#   'd': 8,
#   'e': 0,
#   'f': 2,
#   'g': 11,
#   'h': 0,
#   'i': 462,
#   'j': 0,
#   'k': 0,
#   'l': 7,
#   'm': 25,
#   'n': 16,
#   'o': 0,
#   'p': 4,
#   'q': 0,
#   'r': 1,
#   's': 1,
#   't': 31,
#   'u': 5,
#   'v': 6,
#   'w': 14,
#   'x': 0,
#   'y': 71,
#   'z': 0,
#   ' ': 2},
#  'ta': {'a': 0,
#   'b': 30,
#   'c': 10,
#   'd': 0,
#   'e': 0,
#   'f': 1,
#   'g': 6,
#   'h': 0,
#   'i': 47,
#   'j': 0,
#   'k': 37,
#   'l': 52,
#   'm': 3,
#   'n': 58,
#   'o': 0,
#   'p': 3,
#   'q': 0,
#   'r': 26,
#   's': 7,
#   't': 41,
#   'u': 4,
#   'v': 0,
#   'w': 0,
#   'x': 7,
#   'y': 6,
#   'z': 0,
#   ' ': 0},
#  'ua': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 5,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 16,
#   'm': 0,
#   'n': 1,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 6,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'va': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 5,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 13,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 4,
#   's': 1,
#   't': 3,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'wa': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 2,
#   'h': 0,
#   'i': 24,
#   'j': 0,
#   'k': 2,
#   'l': 26,
#   'm': 6,
#   'n': 21,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 14,
#   's': 378,
#   't': 19,
#   'u': 0,
#   'v': 5,
#   'w': 0,
#   'x': 0,
#   'y': 103,
#   'z': 0,
#   ' ': 0},
#  'xa': {'a': 0,
#   'b': 0,
#   'c': 9,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 3,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ya': {'a': 0,
#   'b': 2,
#   'c': 0,
#   'd': 2,
#   'e': 0,
#   'f': 1,
#   'g': 1,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 11,
#   'm': 0,
#   'n': 4,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 8,
#   's': 1,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 4,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'za': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 1,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 6,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  ' a': {'a': 0,
#   'b': 100,
#   'c': 39,
#   'd': 54,
#   'e': 0,
#   'f': 57,
#   'g': 120,
#   'h': 5,
#   'i': 15,
#   'j': 0,
#   'k': 0,
#   'l': 567,
#   'm': 34,
#   'n': 1009,
#   'o': 0,
#   'p': 20,
#   'q': 0,
#   'r': 110,
#   's': 307,
#   't': 223,
#   'u': 3,
#   'v': 5,
#   'w': 30,
#   'x': 2,
#   'y': 0,
#   'z': 0,
#   ' ': 600},
#  'ab': {'a': 0,
#   'b': 54,
#   'c': 0,
#   'd': 0,
#   'e': 7,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 7,
#   'j': 0,
#   'k': 0,
#   'l': 48,
#   'm': 0,
#   'n': 0,
#   'o': 106,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 3,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 15,
#   'z': 0,
#   ' ': 1},
#  'bb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 2,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 59,
#   'j': 0,
#   'k': 0,
#   'l': 7,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'cb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'db': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 7,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 3,
#   'z': 0,
#   ' ': 0},
#  'eb': {'a': 2,
#   'b': 2,
#   'c': 0,
#   'd': 0,
#   'e': 11,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 5,
#   'j': 0,
#   'k': 0,
#   'l': 4,
#   'm': 0,
#   'n': 0,
#   'o': 22,
#   'p': 0,
#   'q': 0,
#   'r': 3,
#   's': 4,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 1,
#   'z': 0,
#   ' ': 1},
#  'fb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'gb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'hb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 2,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ib': {'a': 0,
#   'b': 5,
#   'c': 0,
#   'd': 0,
#   'e': 3,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 11,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 31,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'jb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'kb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'lb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 4,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'mb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 30,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 25,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 2,
#   's': 5,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 1},
#  'nb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 97,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ob': {'a': 0,
#   'b': 4,
#   'c': 0,
#   'd': 0,
#   'e': 4,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 5,
#   'm': 0,
#   'n': 0,
#   'o': 8,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 21,
#   't': 5,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'pb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 2,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'qb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'rb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'sb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'tb': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 2,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 1,
#   'z': 0,
#   ' ': 0},
#  'ub': {'a': 0,
#   'b': 3,
#   'c': 0,
#   'd': 1,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 8,
#   'k': 0,
#   'l': 12,
#   'm': 1,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 2,
#   't': 8,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'vb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'wb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'xb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'yb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 4,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 8,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'zb': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  ' b': {'a': 76,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 449,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 42,
#   'j': 0,
#   'k': 0,
#   'l': 11,
#   'm': 0,
#   'n': 0,
#   'o': 64,
#   'p': 0,
#   'q': 0,
#   'r': 53,
#   's': 0,
#   't': 0,
#   'u': 138,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 76,
#   'z': 0,
#   ' ': 0},
#  'ac': {'a': 0,
#   'b': 0,
#   'c': 28,
#   'd': 0,
#   'e': 48,
#   'f': 0,
#   'g': 0,
#   'h': 24,
#   'i': 2,
#   'j': 0,
#   'k': 48,
#   'l': 11,
#   'm': 0,
#   'n': 0,
#   'o': 4,
#   'p': 0,
#   'q': 0,
#   'r': 5,
#   's': 0,
#   't': 31,
#   'u': 7,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'bc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'cc': {'a': 2,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 20,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 3,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 5,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 6,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'dc': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 1,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 2,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ec': {'a': 23,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 23,
#   'f': 0,
#   'g': 0,
#   'h': 8,
#   'i': 12,
#   'j': 0,
#   'k': 14,
#   'l': 3,
#   'm': 0,
#   'n': 0,
#   'o': 32,
#   'p': 0,
#   'q': 0,
#   'r': 3,
#   's': 0,
#   't': 189,
#   'u': 22,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'fc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 3,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'gc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 2,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'hc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 1,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ic': {'a': 17,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 516,
#   'f': 0,
#   'g': 0,
#   'h': 58,
#   'i': 8,
#   'j': 0,
#   'k': 22,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 1,
#   't': 13,
#   'u': 15,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 33},
#  'jc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 1,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'kc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'lc': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 3,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 2,
#   'p': 0,
#   'q': 0,
#   'r': 3,
#   's': 0,
#   't': 0,
#   'u': 2,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'mc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'nc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 137,
#   'f': 0,
#   'g': 0,
#   'h': 26,
#   'i': 11,
#   'j': 0,
#   'k': 0,
#   'l': 19,
#   'm': 0,
#   'n': 0,
#   'o': 13,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 8,
#   'z': 0,
#   ' ': 0},
#  'oc': {'a': 6,
#   'b': 0,
#   'c': 5,
#   'd': 0,
#   'e': 9,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 8,
#   'j': 0,
#   'k': 84,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'pc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'qc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'rc': {'a': 3,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 2,
#   'f': 0,
#   'g': 0,
#   'h': 66,
#   'i': 3,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 3,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 2,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'sc': {'a': 6,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 10,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 5,
#   'm': 0,
#   'n': 0,
#   'o': 10,
#   'p': 0,
#   'q': 0,
#   'r': 15,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'tc': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 41,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 4,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'uc': {'a': 3,
#   'b': 0,
#   'c': 3,
#   'd': 0,
#   'e': 10,
#   'f': 0,
#   'g': 0,
#   'h': 146,
#   'i': 1,
#   'j': 0,
#   'k': 13,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 3,
#   'u': 6,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'vc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'wc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'xc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 10,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 8,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'yc': {'a': 4,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 3,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 4,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'zc': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  ' c': {'a': 274,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 20,
#   'f': 0,
#   'g': 0,
#   'h': 106,
#   'i': 6,
#   'j': 0,
#   'k': 0,
#   'l': 35,
#   'm': 0,
#   'n': 0,
#   'o': 338,
#   'p': 0,
#   'q': 0,
#   'r': 91,
#   's': 0,
#   't': 0,
#   'u': 48,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ad': {'a': 5,
#   'b': 1,
#   'c': 1,
#   'd': 37,
#   'e': 56,
#   'f': 8,
#   'g': 0,
#   'h': 1,
#   'i': 13,
#   'j': 1,
#   'k': 0,
#   'l': 6,
#   'm': 0,
#   'n': 10,
#   'o': 4,
#   'p': 1,
#   'q': 0,
#   'r': 7,
#   's': 13,
#   't': 1,
#   'u': 0,
#   'v': 20,
#   'w': 1,
#   'x': 0,
#   'y': 15,
#   'z': 0,
#   ' ': 235},
#  'bd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'cd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'dd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 43,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 9,
#   'j': 0,
#   'k': 0,
#   'l': 12,
#   'm': 0,
#   'n': 0,
#   'o': 2,
#   'p': 0,
#   'q': 0,
#   'r': 6,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 2,
#   'z': 0,
#   ' ': 1},
#  'ed': {'a': 6,
#   'b': 2,
#   'c': 0,
#   'd': 2,
#   'e': 6,
#   'f': 1,
#   'g': 21,
#   'h': 2,
#   'i': 36,
#   'j': 0,
#   'k': 0,
#   'l': 8,
#   'm': 1,
#   'n': 4,
#   'o': 10,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 10,
#   't': 12,
#   'u': 9,
#   'v': 0,
#   'w': 6,
#   'x': 0,
#   'y': 2,
#   'z': 0,
#   ' ': 770},
#  'fd': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'gd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'hd': {'a': 2,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'id': {'a': 6,
#   'b': 0,
#   'c': 0,
#   'd': 13,
#   'e': 105,
#   'f': 0,
#   'g': 5,
#   'h': 0,
#   'i': 8,
#   'j': 0,
#   'k': 0,
#   'l': 13,
#   'm': 0,
#   'n': 16,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 1,
#   't': 4,
#   'u': 4,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 2,
#   'z': 0,
#   ' ': 492},
#  'jd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'kd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ld': {'a': 2,
#   'b': 2,
#   'c': 0,
#   'd': 0,
#   'e': 28,
#   'f': 3,
#   'g': 0,
#   'h': 2,
#   'i': 15,
#   'j': 0,
#   'k': 1,
#   'l': 3,
#   'm': 0,
#   'n': 28,
#   'o': 1,
#   'p': 1,
#   'q': 0,
#   'r': 12,
#   's': 0,
#   't': 1,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 208},
#  'md': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'nd': {'a': 33,
#   'b': 6,
#   'c': 3,
#   'd': 2,
#   'e': 113,
#   'f': 2,
#   'g': 0,
#   'h': 5,
#   'i': 34,
#   'j': 0,
#   'k': 0,
#   'l': 8,
#   'm': 2,
#   'n': 3,
#   'o': 13,
#   'p': 3,
#   'q': 0,
#   'r': 5,
#   's': 36,
#   't': 16,
#   'u': 2,
#   'v': 1,
#   'w': 4,
#   'x': 0,
#   'y': 3,
#   'z': 0,
#   ' ': 1033},
#  'od': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 2,
#   'e': 5,
#   'f': 1,
#   'g': 2,
#   'h': 0,
#   'i': 4,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 14,
#   'p': 1,
#   'q': 0,
#   'r': 1,
#   's': 1,
#   't': 0,
#   'u': 8,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 28,
#   'z': 0,
#   ' ': 31},
#  'pd': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'qd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'rd': {'a': 8,
#   'b': 1,
#   'c': 0,
#   'd': 0,
#   'e': 36,
#   'f': 0,
#   'g': 0,
#   'h': 1,
#   'i': 7,
#   'j': 0,
#   'k': 0,
#   'l': 12,
#   'm': 0,
#   'n': 0,
#   'o': 10,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 43,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 50},
#  'sd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'td': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 5,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ud': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 19,
#   'e': 14,
#   'f': 0,
#   'g': 5,
#   'h': 0,
#   'i': 10,
#   'j': 0,
#   'k': 0,
#   'l': 3,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 5},
#  'vd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'wd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 6,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 4},
#  'xd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'yd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 5,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 2,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'zd': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  ' d': {'a': 68,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 101,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 179,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 393,
#   'p': 0,
#   'q': 0,
#   'r': 55,
#   's': 0,
#   't': 0,
#   'u': 46,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ae': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'be': {'a': 34,
#   'b': 1,
#   'c': 24,
#   'd': 6,
#   'e': 40,
#   'f': 43,
#   'g': 108,
#   'h': 18,
#   'i': 20,
#   'j': 0,
#   'k': 1,
#   'l': 30,
#   'm': 1,
#   'n': 4,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 124,
#   's': 18,
#   't': 21,
#   'u': 1,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 1,
#   'z': 0,
#   ' ': 144},
#  'ce': {'a': 3,
#   'b': 1,
#   'c': 3,
#   'd': 18,
#   'e': 5,
#   'f': 1,
#   'g': 1,
#   'h': 2,
#   'i': 12,
#   'j': 0,
#   'k': 0,
#   'l': 6,
#   'm': 6,
#   'n': 19,
#   'o': 2,
#   'p': 17,
#   'q': 0,
#   'r': 30,
#   's': 39,
#   't': 2,
#   'u': 0,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 339},
#  'de': {'a': 66,
#   'b': 0,
#   'c': 10,
#   'd': 81,
#   'e': 28,
#   'f': 8,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 9,
#   'm': 18,
#   'n': 73,
#   'o': 1,
#   'p': 2,
#   'q': 0,
#   'r': 125,
#   's': 27,
#   't': 2,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 57},
#  'ee': {'a': 1,
#   'b': 3,
#   'c': 3,
#   'd': 32,
#   'e': 0,
#   'f': 1,
#   'g': 1,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 7,
#   'l': 29,
#   'm': 58,
#   'n': 146,
#   'o': 0,
#   'p': 56,
#   'q': 0,
#   'r': 24,
#   's': 13,
#   't': 26,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 2,
#   'y': 0,
#   'z': 14,
#   ' ': 101},
#  'fe': {'a': 7,
#   'b': 1,
#   'c': 15,
#   'd': 3,
#   'e': 52,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 35,
#   'm': 0,
#   'n': 12,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 17,
#   's': 1,
#   't': 7,
#   'u': 0,
#   'v': 0,
#   'w': 10,
#   'x': 1,
#   'y': 0,
#   'z': 0,
#   ' ': 4},
#  'ge': {'a': 2,
#   'b': 0,
#   'c': 0,
#   'd': 27,
#   'e': 0,
#   'f': 1,
#   'g': 0,
#   'h': 10,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 1,
#   'n': 22,
#   'o': 13,
#   'p': 0,
#   'q': 0,
#   'r': 32,
#   's': 14,
#   't': 90,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 74},
#  'he': {'a': 140,
#   'b': 14,
#   'c': 28,
#   'd': 65,
#   'e': 10,
#   'f': 10,
#   'g': 7,
#   'h': 11,
#   'i': 58,
#   'j': 1,
#   'k': 4,
#   'l': 33,
#   'm': 99,
#   'n': 183,
#   'o': 4,
#   'p': 14,
#   'q': 5,
#   'r': 698,
#   's': 104,
#   't': 24,
#   'u': 3,
#   'v': 1,
#   'w': 16,
#   'x': 0,
#   'y': 154,
#   'z': 0,
#   ' ': 2288},
#  'ie': {'a': 0,
#   'b': 0,
#   'c': 10,
#   'd': 102,
#   'e': 0,
#   'f': 5,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 7,
#   'l': 1,
#   'm': 0,
#   'n': 15,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 16,
#   's': 30,
#   't': 11,
#   'u': 2,
#   'v': 11,
#   'w': 2,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 5},
#  'je': {'a': 0,
#   'b': 0,
#   'c': 93,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 12,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ke': {'a': 1,
#   'b': 0,
#   'c': 1,
#   'd': 117,
#   'e': 17,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 5,
#   'm': 0,
#   'n': 11,
#   'o': 1,
#   'p': 13,
#   'q': 0,
#   'r': 6,
#   's': 20,
#   't': 11,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 12,
#   'z': 0,
#   ' ': 133},
#  'le': {'a': 94,
#   'b': 3,
#   'c': 41,
#   'd': 74,
#   'e': 21,
#   'f': 18,
#   'g': 11,
#   'h': 2,
#   'i': 3,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 9,
#   'n': 41,
#   'o': 1,
#   'p': 1,
#   'q': 2,
#   'r': 6,
#   's': 64,
#   't': 44,
#   'u': 0,
#   'v': 3,
#   'w': 6,
#   'x': 0,
#   'y': 1,
#   'z': 0,
#   ' ': 259},
#  'me': {'a': 37,
#   'b': 8,
#   'c': 0,
#   'd': 59,
#   'e': 7,
#   'f': 0,
#   'g': 0,
#   'h': 2,
#   'i': 0,
#   'j': 1,
#   'k': 0,
#   'l': 14,
#   'm': 22,
#   'n': 92,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 16,
#   's': 22,
#   't': 33,
#   'u': 0,
#   'v': 1,
#   'w': 4,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 250},
#  'ne': {'a': 47,
#   'b': 0,
#   'c': 8,
#   'd': 71,
#   'e': 22,
#   'f': 1,
#   'g': 2,
#   'h': 1,
#   'i': 4,
#   'j': 0,
#   'k': 0,
#   'l': 4,
#   'm': 0,
#   'n': 5,
#   'o': 2,
#   'p': 1,
#   'q': 0,
#   'r': 57,
#   's': 35,
#   't': 1,
#   'u': 0,
#   'v': 52,
#   'w': 26,
#   'x': 30,
#   'y': 11,
#   'z': 0,
#   ' ': 137},
#  'oe': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 46,
#   't': 0,
#   'u': 0,
#   'v': 3,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'pe': {'a': 61,
#   'b': 2,
#   'c': 14,
#   'd': 30,
#   'e': 9,
#   'f': 1,
#   'g': 1,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 2,
#   'm': 0,
#   'n': 66,
#   'o': 16,
#   'p': 9,
#   'q': 0,
#   'r': 99,
#   's': 3,
#   't': 5,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 6},
#  'qe': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  're': {'a': 194,
#   'b': 1,
#   'c': 31,
#   'd': 92,
#   'e': 96,
#   'f': 20,
#   'g': 6,
#   'h': 4,
#   'i': 2,
#   'j': 1,
#   'k': 0,
#   'l': 18,
#   'm': 80,
#   'n': 32,
#   'o': 0,
#   'p': 69,
#   'q': 7,
#   'r': 8,
#   's': 85,
#   't': 25,
#   'u': 1,
#   'v': 6,
#   'w': 11,
#   'x': 1,
#   'y': 3,
#   'z': 0,
#   ' ': 401},
#  'se': {'a': 22,
#   'b': 1,
#   'c': 19,
#   'd': 75,
#   'e': 126,
#   'f': 2,
#   'g': 1,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 132,
#   'm': 3,
#   'n': 43,
#   'o': 1,
#   'p': 2,
#   'q': 1,
#   'r': 25,
#   's': 19,
#   't': 38,
#   'u': 0,
#   'v': 18,
#   'w': 0,
#   'x': 0,
#   'y': 5,
#   'z': 0,
#   ' ': 219},
#  'te': {'a': 48,
#   'b': 0,
#   'c': 9,
#   'd': 156,
#   'e': 12,
#   'f': 1,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 1,
#   'k': 0,
#   'l': 57,
#   'm': 15,
#   'n': 167,
#   'o': 2,
#   'p': 3,
#   'q': 0,
#   'r': 339,
#   's': 45,
#   't': 1,
#   'u': 1,
#   'v': 5,
#   'w': 1,
#   'x': 5,
#   'y': 0,
#   'z': 0,
#   ' ': 150},
#  'ue': {'a': 4,
#   'b': 0,
#   'c': 1,
#   'd': 11,
#   'e': 92,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 1,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 2,
#   's': 32,
#   't': 14,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 1,
#   'y': 0,
#   'z': 0,
#   ' ': 3},
#  've': {'a': 0,
#   'b': 2,
#   'c': 0,
#   'd': 28,
#   'e': 0,
#   'f': 0,
#   'g': 1,
#   'h': 2,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 9,
#   'm': 1,
#   'n': 65,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 369,
#   's': 31,
#   't': 4,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 1,
#   'z': 0,
#   ' ': 222},
#  'we': {'a': 3,
#   'b': 5,
#   'c': 0,
#   'd': 15,
#   'e': 11,
#   'f': 0,
#   'g': 0,
#   'h': 1,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 69,
#   'm': 0,
#   'n': 87,
#   'o': 0,
#   'p': 1,
#   'q': 1,
#   'r': 107,
#   's': 1,
#   't': 2,
#   'u': 0,
#   'v': 21,
#   'w': 1,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 36},
#  'xe': {'a': 0,
#   'b': 0,
#   'c': 19,
#   'd': 4,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 2,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 2,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ye': {'a': 5,
#   'b': 0,
#   'c': 0,
#   'd': 4,
#   'e': 2,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 4,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 8,
#   's': 45,
#   't': 25,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 4},
#  'ze': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 4,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 8,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 10},
#  ' e': {'a': 63,
#   'b': 13,
#   'c': 0,
#   'd': 13,
#   'e': 2,
#   'f': 7,
#   'g': 6,
#   'h': 0,
#   'i': 8,
#   'j': 0,
#   'k': 0,
#   'l': 41,
#   'm': 6,
#   'n': 61,
#   'o': 0,
#   'p': 0,
#   'q': 3,
#   'r': 1,
#   's': 6,
#   't': 0,
#   'u': 0,
#   'v': 71,
#   'w': 0,
#   'x': 73,
#   'y': 35,
#   'z': 0,
#   ' ': 0},
#  'af': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 2,
#   'f': 4,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 13,
#   's': 0,
#   't': 45,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'bf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'cf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'df': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 2,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 8,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ef': {'a': 2,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 12,
#   'f': 8,
#   'g': 0,
#   'h': 0,
#   'i': 5,
#   'j': 0,
#   'k': 0,
#   'l': 2,
#   'm': 0,
#   'n': 0,
#   'o': 44,
#   'p': 0,
#   'q': 0,
#   'r': 5,
#   's': 0,
#   't': 16,
#   'u': 20,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 1},
#  'ff': {'a': 3,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 30,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 16,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 6,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 48},
#  'gf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 4,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'hf': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'if': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 17,
#   'f': 18,
#   'g': 0,
#   'h': 0,
#   'i': 9,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 1,
#   't': 6,
#   'u': 19,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 7,
#   'z': 0,
#   ' ': 113},
#  'jf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'kf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'lf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 1,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 1,
#   't': 3,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 77},
#  'mf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 8,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'nf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 15,
#   'p': 0,
#   'q': 0,
#   'r': 2,
#   's': 0,
#   't': 0,
#   'u': 14,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'of': {'a': 6,
#   'b': 0,
#   'c': 3,
#   'd': 1,
#   'e': 4,
#   'f': 97,
#   'g': 1,
#   'h': 0,
#   'i': 5,
#   'j': 0,
#   'k': 0,
#   'l': 2,
#   'm': 2,
#   'n': 1,
#   'o': 1,
#   'p': 1,
#   'q': 0,
#   'r': 3,
#   's': 1,
#   't': 18,
#   'u': 1,
#   'v': 1,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 592},
#  'pf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'qf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'rf': {'a': 2,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 4,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 8,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 3,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'sf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'tf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 1,
#   'm': 0,
#   'n': 0,
#   'o': 3,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 12,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'uf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 5,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'vf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'wf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 5,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'xf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'yf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 3,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'zf': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  ' f': {'a': 99,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 102,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 136,
#   'j': 0,
#   'k': 0,
#   'l': 27,
#   'm': 0,
#   'n': 0,
#   'o': 303,
#   'p': 0,
#   'q': 0,
#   'r': 78,
#   's': 0,
#   't': 0,
#   'u': 39,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ag': {'a': 93,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 59,
#   'f': 0,
#   'g': 1,
#   'h': 0,
#   'i': 6,
#   'j': 0,
#   'k': 0,
#   'l': 3,
#   'm': 0,
#   'n': 0,
#   'o': 4,
#   'p': 1,
#   'q': 0,
#   'r': 48,
#   's': 1,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 1},
#  'bg': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'cg': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'dg': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 29,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 2,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'eg': {'a': 64,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 3,
#   'f': 0,
#   'g': 9,
#   'h': 0,
#   'i': 35,
#   'j': 0,
#   'k': 0,
#   'l': 3,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 9,
#   's': 4,
#   't': 0,
#   'u': 10,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 7},
#  'fg': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'gg': {'a': 2,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 4,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 4,
#   'j': 0,
#   'k': 0,
#   'l': 2,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 5,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'hg': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 1,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ig': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 17,
#   'f': 0,
#   'g': 5,
#   'h': 174,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 11,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 6,
#   't': 0,
#   'u': 4,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 1,
#   ' ': 4},
#  'jg': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
# ...
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'zy': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 1,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  ' y': {'a': 4,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 31,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 470,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'az': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 2,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 2,
#   'z': 0,
#   ' ': 0},
#  'bz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'cz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'dz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'ez': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 8,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 6,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'fz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'gz': {'a': 1,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'hz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'iz': {'a': 6,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 21,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'jz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'kz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'lz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'mz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'nz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'oz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'pz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'qz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'rz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'sz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'tz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'uz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 14,
#   ' ': 0},
#  'vz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'wz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'xz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'yz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'zz': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 14,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  ' z': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 1,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 1,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'a ': {'a': 7,
#   'b': 34,
#   'c': 56,
#   'd': 32,
#   'e': 0,
#   'f': 34,
#   'g': 40,
#   'h': 18,
#   'i': 0,
#   'j': 3,
#   'k': 5,
#   'l': 116,
#   'm': 45,
#   'n': 18,
#   'o': 3,
#   'p': 40,
#   'q': 3,
#   'r': 33,
#   's': 55,
#   't': 45,
#   'u': 4,
#   'v': 27,
#   'w': 36,
#   'x': 0,
#   'y': 1,
#   'z': 0,
#   ' ': 0},
#  'b ': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 1,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 1,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'c ': {'a': 2,
#   'b': 2,
#   'c': 0,
#   'd': 2,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 1,
#   't': 1,
#   'u': 0,
#   'v': 0,
#   'w': 27,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'd ': {'a': 391,
#   'b': 136,
#   'c': 46,
#   'd': 63,
#   'e': 31,
#   'f': 75,
#   'g': 50,
#   'h': 161,
#   'i': 179,
#   'j': 11,
#   'k': 7,
#   'l': 55,
#   'm': 57,
#   'n': 110,
#   'o': 145,
#   'p': 43,
#   'q': 13,
#   'r': 49,
#   's': 194,
#   't': 770,
#   'u': 41,
#   'v': 24,
#   'w': 126,
#   'x': 0,
#   'y': 41,
#   'z': 0,
#   ' ': 0},
#  'e ': {'a': 306,
#   'b': 149,
#   'c': 281,
#   'd': 251,
#   'e': 71,
#   'f': 214,
#   'g': 169,
#   'h': 265,
#   'i': 193,
#   'j': 39,
#   'k': 103,
#   'l': 147,
#   'm': 241,
#   'n': 92,
#   'o': 320,
#   'p': 173,
#   'q': 87,
#   'r': 166,
#   's': 394,
#   't': 542,
#   'u': 52,
#   'v': 29,
#   'w': 451,
#   'x': 0,
#   'y': 62,
#   'z': 0,
#   ' ': 0},
#  'f ': {'a': 73,
#   'b': 20,
#   'c': 44,
#   'd': 10,
#   'e': 16,
#   'f': 10,
#   'g': 10,
#   'h': 59,
#   'i': 66,
#   'j': 1,
#   'k': 3,
#   'l': 17,
#   'm': 24,
#   'n': 9,
#   'o': 18,
#   'p': 19,
#   'q': 1,
#   'r': 12,
#   's': 42,
#   't': 259,
#   'u': 11,
#   'v': 8,
#   'w': 27,
#   'x': 0,
#   'y': 51,
#   'z': 0,
#   ' ': 0},
#  'g ': {'a': 132,
#   'b': 23,
#   'c': 11,
#   'd': 24,
#   'e': 14,
#   'f': 24,
#   'g': 3,
#   'h': 52,
#   'i': 70,
#   'j': 2,
#   'k': 1,
#   'l': 28,
#   'm': 24,
#   'n': 9,
#   'o': 94,
#   'p': 19,
#   'q': 6,
#   'r': 15,
#   's': 49,
#   't': 179,
#   'u': 18,
#   'v': 15,
#   'w': 33,
#   'x': 0,
#   'y': 10,
#   'z': 0,
#   ' ': 0},
#  'h ': {'a': 104,
#   'b': 5,
#   'c': 14,
#   'd': 12,
#   'e': 7,
#   'f': 8,
#   'g': 5,
#   'h': 65,
#   'i': 40,
#   'j': 0,
#   'k': 1,
#   'l': 7,
#   'm': 15,
#   'n': 4,
#   'o': 46,
#   'p': 15,
#   'q': 0,
#   'r': 2,
#   's': 36,
#   't': 122,
#   'u': 4,
#   'v': 1,
#   'w': 28,
#   'x': 0,
#   'y': 16,
#   'z': 0,
#   ' ': 0},
#  'i ': {'a': 14,
#   'b': 12,
#   'c': 39,
#   'd': 50,
#   'e': 6,
#   'f': 3,
#   'g': 12,
#   'h': 31,
#   'i': 0,
#   'j': 0,
#   'k': 14,
#   'l': 5,
#   'm': 23,
#   'n': 12,
#   'o': 8,
#   'p': 3,
#   'q': 2,
#   'r': 1,
#   's': 54,
#   't': 26,
#   'u': 2,
#   'v': 1,
#   'w': 42,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'j ': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'k ': {'a': 48,
#   'b': 4,
#   'c': 2,
#   'd': 2,
#   'e': 4,
#   'f': 7,
#   'g': 1,
#   'h': 13,
#   'i': 34,
#   'j': 1,
#   'k': 1,
#   'l': 5,
#   'm': 10,
#   'n': 7,
#   'o': 37,
#   'p': 1,
#   'q': 1,
#   'r': 2,
#   's': 6,
#   't': 103,
#   'u': 7,
#   'v': 4,
#   'w': 12,
#   'x': 0,
#   'y': 13,
#   'z': 0,
#   ' ': 0},
#  'l ': {'a': 41,
#   'b': 22,
#   'c': 19,
#   'd': 17,
#   'e': 14,
#   'f': 14,
#   'g': 9,
#   'h': 28,
#   'i': 32,
#   'j': 4,
#   'k': 2,
#   'l': 11,
#   'm': 26,
#   'n': 10,
#   'o': 41,
#   'p': 21,
#   'q': 1,
#   'r': 28,
#   's': 58,
#   't': 91,
#   'u': 6,
#   'v': 6,
#   'w': 29,
#   'x': 0,
#   'y': 27,
#   'z': 1,
#   ' ': 0},
#  'm ': {'a': 45,
#   'b': 9,
#   'c': 7,
#   'd': 9,
#   'e': 20,
#   'f': 8,
#   'g': 7,
#   'h': 9,
#   'i': 18,
#   'j': 0,
#   'k': 1,
#   'l': 7,
#   'm': 6,
#   'n': 8,
#   'o': 20,
#   'p': 4,
#   'q': 2,
#   'r': 5,
#   's': 19,
#   't': 45,
#   'u': 4,
#   'v': 2,
#   'w': 22,
#   'x': 0,
#   'y': 1,
#   'z': 0,
#   ' ': 0},
#  'n ': {'a': 290,
#   'b': 30,
#   'c': 35,
#   'd': 17,
#   'e': 28,
#   'f': 35,
#   'g': 13,
#   'h': 81,
#   'i': 144,
#   'j': 4,
#   'k': 9,
#   'l': 23,
#   'm': 34,
#   'n': 16,
#   'o': 87,
#   'p': 21,
#   'q': 2,
#   'r': 28,
#   's': 101,
#   't': 315,
#   'u': 10,
#   'v': 6,
#   'w': 76,
#   'x': 0,
#   'y': 23,
#   'z': 0,
#   ' ': 0},
#  'o ': {'a': 97,
#   'b': 82,
#   'c': 46,
#   'd': 48,
#   'e': 21,
#   'f': 39,
#   'g': 46,
#   'h': 117,
#   'i': 48,
#   'j': 1,
#   'k': 9,
#   'l': 44,
#   'm': 57,
#   'n': 26,
#   'o': 44,
#   'p': 33,
#   'q': 3,
#   'r': 29,
#   's': 142,
#   't': 183,
#   'u': 14,
#   'v': 2,
#   'w': 52,
#   'x': 0,
#   'y': 35,
#   'z': 0,
#   ' ': 0},
#  'p ': {'a': 40,
#   'b': 7,
#   'c': 3,
#   'd': 1,
#   'e': 1,
#   'f': 1,
#   'g': 0,
#   'h': 2,
#   'i': 24,
#   'j': 0,
#   'k': 1,
#   'l': 4,
#   'm': 3,
#   'n': 2,
#   'o': 26,
#   'p': 2,
#   'q': 0,
#   'r': 0,
#   's': 4,
#   't': 26,
#   'u': 2,
#   'v': 4,
#   'w': 4,
#   'x': 0,
#   'y': 2,
#   'z': 0,
#   ' ': 0},
#  'q ': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'r ': {'a': 152,
#   'b': 22,
#   'c': 41,
#   'd': 36,
#   'e': 40,
#   'f': 62,
#   'g': 16,
#   'h': 109,
#   'i': 76,
#   'j': 2,
#   'k': 10,
#   'l': 40,
#   'm': 37,
#   'n': 26,
#   'o': 75,
#   'p': 33,
#   'q': 8,
#   'r': 18,
#   's': 106,
#   't': 190,
#   'u': 11,
#   'v': 19,
#   'w': 77,
#   'x': 6,
#   'y': 17,
#   'z': 0,
#   ' ': 0},
#  's ': {'a': 275,
#   'b': 52,
#   'c': 60,
#   'd': 28,
#   'e': 49,
#   'f': 67,
#   'g': 47,
#   'h': 92,
#   'i': 139,
#   'j': 8,
#   'k': 4,
#   'l': 46,
#   'm': 61,
#   'n': 74,
#   'o': 145,
#   'p': 34,
#   'q': 13,
#   'r': 27,
#   's': 180,
#   't': 277,
#   'u': 17,
#   'v': 31,
#   'w': 122,
#   'x': 0,
#   'y': 20,
#   'z': 0,
#   ' ': 0},
#  't ': {'a': 302,
#   'b': 105,
#   'c': 65,
#   'd': 86,
#   'e': 34,
#   'f': 65,
#   'g': 111,
#   'h': 162,
#   'i': 284,
#   'j': 11,
#   'k': 18,
#   'l': 81,
#   'm': 87,
#   'n': 36,
#   'o': 240,
#   'p': 59,
#   'q': 16,
#   'r': 41,
#   's': 203,
#   't': 434,
#   'u': 43,
#   'v': 22,
#   'w': 215,
#   'x': 0,
#   'y': 55,
#   'z': 0,
#   ' ': 0},
#  'u ': {'a': 30,
#   'b': 5,
#   'c': 35,
#   'd': 28,
#   'e': 5,
#   'f': 13,
#   'g': 12,
#   'h': 16,
#   'i': 6,
#   'j': 5,
#   'k': 42,
#   'l': 11,
#   'm': 43,
#   'n': 6,
#   'o': 11,
#   'p': 13,
#   'q': 0,
#   'r': 2,
#   's': 24,
#   't': 20,
#   'u': 1,
#   'v': 0,
#   'w': 25,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'v ': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'w ': {'a': 25,
#   'b': 3,
#   'c': 5,
#   'd': 10,
#   'e': 4,
#   'f': 6,
#   'g': 1,
#   'h': 12,
#   'i': 25,
#   'j': 0,
#   'k': 0,
#   'l': 7,
#   'm': 14,
#   'n': 2,
#   'o': 10,
#   'p': 2,
#   'q': 1,
#   'r': 2,
#   's': 13,
#   't': 42,
#   'u': 5,
#   'v': 3,
#   'w': 20,
#   'x': 0,
#   'y': 9,
#   'z': 1,
#   ' ': 0},
#  'x ': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 1,
#   'e': 2,
#   'f': 0,
#   'g': 0,
#   'h': 1,
#   'i': 3,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 3,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 0,
#   't': 3,
#   'u': 0,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'y ': {'a': 130,
#   'b': 31,
#   'c': 39,
#   'd': 54,
#   'e': 18,
#   'f': 35,
#   'g': 30,
#   'h': 37,
#   'i': 64,
#   'j': 4,
#   'k': 11,
#   'l': 43,
#   'm': 49,
#   'n': 19,
#   'o': 72,
#   'p': 38,
#   'q': 4,
#   'r': 32,
#   's': 82,
#   't': 145,
#   'u': 26,
#   'v': 9,
#   'w': 100,
#   'x': 0,
#   'y': 14,
#   'z': 0,
#   ' ': 0},
#  'z ': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  '  ': {'a': 4,
#   'b': 0,
#   'c': 0,
#   'd': 1,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 1,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 5,
#   'u': 0,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 113}}

# %% [markdown]
# We have to start with two letters, so let's find the most common sequence of two letters.
#
# Using Ian's code, convert into dictionary where the key is the combination of two chars and value is the weights. Order this to find most common.

# %%
# Create the weights.
twoghts = {c: {d: sbook.count(c + d) for d in chars} for c in chars}

counts = []
twos = []
for i in chars:
    for j in chars:
        counts.append(twoghts[i][j])
        twos.append(i + j)
twos = dict(zip(twos, counts))

# https://stackoverflow.com/a/613218
dict(sorted(twos.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'e ': 4843,
#  ' t': 4280,
#  'he': 4011,
#  'th': 3833,
#  ' a': 3304,
#  'd ': 2853,
#  't ': 2818,
#  ' s': 2365,
#  'in': 2264,
#  'er': 2109,
#  's ': 1890,
#  'an': 1776,
#  ' w': 1766,
#  ' i': 1749,
#  'ou': 1704,
#  ' o': 1533,
#  'it': 1492,
#  'n ': 1460,
#  ' h': 1438,
#  'nd': 1411,
#  'at': 1345,
#  're': 1344,
#  'on': 1295,
#  'r ': 1242,
#  'ng': 1232,
#  'o ': 1231,
#  'ha': 1211,
#  'en': 1147,
#  'y ': 1106,
#  'to': 1097,
#  'ed': 1088,
#  'te': 1054,
#  'al': 1018,
#  'as': 944,
#  'li': 941,
#  'or': 937,
#  ' c': 918,
#  ' b': 909,
#  ' m': 900,
#  'se': 896,
#  'sh': 867,
#  'g ': 864,
#  'hi': 860,
#  'ar': 846,
#  ' d': 843,
#  'ea': 835,
#  'f ': 831,
#  'le': 814,
#  'ce': 796,
#  ' f': 784,
#  've': 759,
#  'ai': 752,
#  'of': 749,
#  'll': 748,
#  'ut': 748,
#  ' l': 738,
#  'id': 730,
#  'es': 722,
#  'is': 715,
#  'st': 712,
#  'ic': 689,
#  'sa': 668,
#  'a ': 660,
#  'be': 651,
#  'me': 649,
#  'ti': 636,
#  ' p': 622,
#  'ho': 604,
#  ' g': 601,
#  'wa': 600,
#  'ne': 597,
#  'no': 596,
#  'yo': 586,
#  'nt': 577,
#  'h ': 571,
#  'ow': 566,
#  'l ': 562,
#  'ee': 553,
#  'ro': 543,
#  ' n': 533,
#  'ur': 532,
#  'wh': 530,
#  'de': 525,
#  ' r': 522,
#  'ch': 517,
#  ' y': 505,
#  'el': 501,
#  'ot': 499,
#  'do': 487,
#  'ad': 482,
#  'us': 471,
#  'ly': 468,
#  'oo': 465,
#  'co': 455,
#  'ri': 453,
#  'so': 451,
#  'wi': 444,
#  'fo': 423,
#  ' e': 413,
#  'ry': 393,
#  'et': 386,
#  'ma': 384,
#  'ke': 377,
#  'tt': 376,
#  'rs': 374,
#  'i ': 369,
#  'la': 366,
#  'we': 365,
#  'ra': 361,
#  'u ': 357,
#  'ul': 355,
#  'wo': 354,
#  'ca': 353,
#  'lo': 348,
#  'ld': 346,
#  'il': 345,
#  'gh': 339,
#  'ta': 339,
#  'mo': 338,
#  'om': 336,
#  'di': 331,
#  'pe': 331,
#  'ec': 329,
#  'k ': 327,
#  'un': 327,
#  'em': 324,
#  'ge': 314,
#  'rt': 300,
#  'io': 299,
#  'si': 299,
#  'ay': 294,
#  'tl': 293,
#  ' u': 293,
#  'm ': 281,
#  'gr': 252,
#  'ht': 250,
#  ' k': 245,
#  'ab': 243,
#  'im': 243,
#  'ss': 243,
#  'tr': 242,
#  'bu': 239,
#  'ig': 237,
#  'ct': 236,
#  'ga': 234,
#  'pr': 233,
#  'w ': 231,
#  'bo': 228,
#  'ir': 228,
#  ' v': 225,
#  'ey': 224,
#  'ie': 223,
#  'ok': 223,
#  'pl': 222,
#  'qu': 222,
#  'up': 222,
#  'ni': 221,
#  'ag': 220,
#  'nc': 215,
#  'ki': 213,
#  'tu': 210,
#  'ac': 208,
#  'ev': 205,
#  'ns': 205,
#  'am': 202,
#  'go': 202,
#  'mi': 201,
#  'ol': 200,
#  'ts': 200,
#  'po': 199,
#  'if': 193,
#  'fi': 190,
#  'ep': 188,
#  'uc': 186,
#  'rd': 185,
#  'ck': 182,
#  'fe': 179,
#  'av': 178,
#  'rg': 175,
#  'su': 175,
#  'ug': 175,
#  '  ': 173,
#  ' q': 171,
#  'ue': 169,
#  'op': 160,
#  'p ': 160,
#  'pa': 159,
#  'rk': 155,
#  'os': 154,
#  'ap': 147,
#  'lf': 147,
#  'wn': 147,
#  'eg': 145,
#  'pi': 144,
#  'na': 141,
#  'gu': 140,
#  'kn': 139,
#  'ny': 138,
#  'da': 137,
#  'mu': 136,
#  'rm': 136,
#  'ff': 132,
#  'ak': 131,
#  'oi': 130,
#  'pp': 130,
#  'fu': 126,
#  'cr': 125,
#  'bl': 124,
#  'ex': 123,
#  'bi': 122,
#  'ef': 119,
#  'fa': 116,
#  'nk': 116,
#  'fr': 114,
#  'cu': 113,
#  'oc': 113,
#  'ei': 112,
#  'od': 110,
#  'ov': 110,
#  ' j': 107,
#  'je': 106,
#  'iv': 105,
#  'mp': 105,
#  'ds': 104,
#  'ye': 104,
#  'sp': 103,
#  'ju': 102,
#  'by': 101,
#  'nl': 100,
#  'nb': 99,
#  'ik': 97,
#  'rn': 97,
#  'rr': 97,
#  'aw': 96,
#  'vi': 96,
#  'gi': 95,
#  'dr': 94,
#  'tw': 93,
#  'ui': 90,
#  'hr': 89,
#  'ft': 88,
#  'cl': 87,
#  'pt': 86,
#  'oj': 85,
#  'ru': 85,
#  'tm': 84,
#  'ba': 82,
#  'ph': 82,
#  'ty': 82,
#  'au': 80,
#  'rc': 80,
#  'rp': 80,
#  'ew': 79,
#  'pu': 79,
#  'dd': 75,
#  'du': 70,
#  'sl': 70,
#  'vo': 70,
#  'lt': 69,
#  'af': 68,
#  'bb': 68,
#  'my': 68,
#  'gs': 67,
#  'yi': 67,
#  'dl': 65,
#  'ud': 65,
#  'gl': 64,
#  'mb': 64,
#  'sn': 63,
#  'br': 62,
#  'ks': 62,
#  'nu': 62,
#  'dn': 61,
#  'yp': 61,
#  'lk': 60,
#  'um': 60,
#  'ia': 59,
#  'hu': 58,
#  'nn': 57,
#  'oh': 57,
#  'rl': 57,
#  'ci': 56,
#  'eb': 55,
#  'eh': 54,
#  'ib': 53,
#  'dy': 52,
#  'ls': 51,
#  'oe': 51,
#  'py': 50,
#  'sc': 49,
#  'ys': 49,
#  'ob': 48,
#  'sk': 48,
#  'tc': 48,
#  'hy': 47,
#  'ms': 47,
#  'yt': 47,
#  'eo': 45,
#  'og': 42,
#  'sw': 42,
#  'xt': 42,
#  'wr': 38,
#  'cc': 36,
#  'fl': 36,
#  'lu': 36,
#  'bs': 35,
#  'c ': 35,
#  'dt': 35,
#  'ub': 35,
#  'dg': 34,
#  'ya': 34,
#  'nf': 33,
#  'ps': 32,
#  'wl': 32,
#  'ze': 32,
#  'ws': 31,
#  'xp': 31,
#  'ah': 30,
#  'sm': 29,
#  'va': 29,
#  'ua': 28,
#  'iz': 27,
#  'oa': 27,
#  'xe': 27,
#  'xi': 27,
#  'ip': 25,
#  'rh': 25,
#  'kl': 23,
#  'yr': 23,
#  'nv': 22,
#  'oy': 22,
#  'dv': 21,
#  'ek': 19,
#  'eq': 19,
#  'mm': 19,
#  'mn': 19,
#  'rf': 19,
#  'tg': 19,
#  'gg': 18,
#  'gt': 18,
#  'xc': 18,
#  'jo': 17,
#  'lw': 17,
#  'nx': 17,
#  'tf': 17,
#  'lp': 16,
#  'df': 15,
#  'ww': 15,
#  'x ': 15,
#  'ez': 14,
#  'tn': 14,
#  'uz': 14,
#  'zl': 14,
#  'zz': 14,
#  'bt': 13,
#  'gn': 13,
#  'lv': 13,
#  'rw': 13,
#  'yb': 13,
#  'yc': 13,
#  'aj': 12,
#  'ax': 12,
#  'db': 12,
#  'dw': 12,
#  'ii': 12,
#  'nw': 12,
#  'oq': 12,
#  'xa': 12,
#  'dh': 11,
#  'ix': 11,
#  'ka': 11,
#  'lc': 11,
#  'ox': 11,
#  'rv': 11,
#  'wd': 11,
#  'zi': 11,
#  'mf': 10,
#  'sy': 10,
#  'yd': 10,
#  'ym': 10,
#  'iu': 9,
#  'ky': 9,
#  'lm': 9,
#  'td': 9,
#  'bj': 8,
#  'cy': 8,
#  'eu': 8,
#  'hs': 8,
#  'kt': 8,
#  'lr': 8,
#  'nh': 8,
#  'yw': 8,
#  'fy': 7,
#  'np': 7,
#  'sg': 7,
#  'sq': 7,
#  'za': 7,
#  'dp': 6,
#  'hm': 6,
#  'ja': 6,
#  'nq': 6,
#  'yl': 6,
#  ' x': 6,
#  'az': 5,
#  'gf': 5,
#  'hb': 5,
#  'lb': 5,
#  'mt': 5,
#  'sf': 5,
#  'uf': 5,
#  'uk': 5,
#  'wf': 5,
#  'wt': 5,
#  'dc': 4,
#  'ej': 4,
#  'gw': 4,
#  'hd': 4,
#  'hl': 4,
#  'iw': 4,
#  'lh': 4,
#  'ml': 4,
#  'sr': 4,
#  'tb': 4,
#  'yf': 4,
#  'yh': 4,
#  'yn': 4,
#  'ao': 3,
#  'b ': 3,
#  'dm': 3,
#  'fc': 3,
#  'fs': 3,
#  'hc': 3,
#  'hf': 3,
#  'hn': 3,
#  'lg': 3,
#  'mw': 3,
#  'nj': 3,
#  'nr': 3,
#  'pb': 3,
#  'pm': 3,
#  'rb': 3,
#  'rq': 3,
#  'sd': 3,
#  'tk': 3,
#  'tp': 3,
#  'uo': 3,
#  'vy': 3,
#  'yg': 3,
#  'yu': 3,
#  'yy': 3,
#  'fm': 2,
#  'gc': 2,
#  'gp': 2,
#  'gy': 2,
#  'hw': 2,
#  'ko': 2,
#  'ku': 2,
#  'nm': 2,
#  'oz': 2,
#  'pd': 2,
#  'pg': 2,
#  'sv': 2,
#  'tq': 2,
#  'tv': 2,
#  'yk': 2,
#  'zy': 2,
#  ' z': 2,
#  'ae': 1,
#  'bd': 1,
#  'bm': 1,
#  'cs': 1,
#  'dj': 1,
#  'dk': 1,
#  'fd': 1,
#  'fg': 1,
#  'fh': 1,
#  'fn': 1,
#  'fp': 1,
#  'fv': 1,
#  'gb': 1,
#  'gd': 1,
#  'gv': 1,
#  'gz': 1,
#  'hg': 1,
#  'hh': 1,
#  'hj': 1,
#  'hp': 1,
#  'ih': 1,
#  'jc': 1,
#  'kf': 1,
#  'kr': 1,
#  'kw': 1,
#  'mc': 1,
#  'mg': 1,
#  'mh': 1,
#  'pw': 1,
#  'sb': 1,
#  'tx': 1,
#  'uh': 1,
#  'uw': 1,
#  'vu': 1,
#  'wc': 1,
#  'wk': 1,
#  'wm': 1,
#  'wp': 1,
#  'wq': 1,
#  'wv': 1,
#  'aa': 0,
#  'aq': 0,
#  'bc': 0,
#  'bf': 0,
#  'bg': 0,
#  'bh': 0,
#  'bk': 0,
#  'bn': 0,
#  'bp': 0,
#  'bq': 0,
#  'bv': 0,
#  'bw': 0,
#  'bx': 0,
#  'bz': 0,
#  'cb': 0,
#  'cd': 0,
#  'cf': 0,
#  'cg': 0,
#  'cj': 0,
#  'cm': 0,
#  'cn': 0,
#  'cp': 0,
#  'cq': 0,
#  'cv': 0,
#  'cw': 0,
#  'cx': 0,
#  'cz': 0,
#  'dq': 0,
#  'dx': 0,
#  'dz': 0,
#  'fb': 0,
#  'fj': 0,
#  'fk': 0,
#  'fq': 0,
#  'fw': 0,
#  'fx': 0,
#  'fz': 0,
#  'gj': 0,
#  'gk': 0,
#  'gm': 0,
#  'gq': 0,
#  'gx': 0,
#  'hk': 0,
#  'hq': 0,
#  'hv': 0,
#  'hx': 0,
#  'hz': 0,
#  'ij': 0,
#  'iq': 0,
#  'iy': 0,
#  'jb': 0,
#  'jd': 0,
#  'jf': 0,
#  'jg': 0,
#  'jh': 0,
#  'ji': 0,
#  'jj': 0,
#  'jk': 0,
#  'jl': 0,
#  'jm': 0,
#  'jn': 0,
#  'jp': 0,
#  'jq': 0,
#  'jr': 0,
#  'js': 0,
#  'jt': 0,
#  'jv': 0,
#  'jw': 0,
#  'jx': 0,
#  'jy': 0,
#  'jz': 0,
#  'j ': 0,
#  'kb': 0,
#  'kc': 0,
#  'kd': 0,
#  'kg': 0,
#  'kh': 0,
#  'kj': 0,
#  'kk': 0,
#  'km': 0,
#  'kp': 0,
#  'kq': 0,
#  'kv': 0,
#  'kx': 0,
#  'kz': 0,
#  'lj': 0,
#  'ln': 0,
#  'lq': 0,
#  'lx': 0,
#  'lz': 0,
#  'md': 0,
#  'mj': 0,
#  'mk': 0,
#  'mq': 0,
#  'mr': 0,
#  'mv': 0,
#  'mx': 0,
#  'mz': 0,
#  'nz': 0,
#  'pc': 0,
#  'pf': 0,
#  'pj': 0,
#  'pk': 0,
#  'pn': 0,
#  'pq': 0,
#  'pv': 0,
#  'px': 0,
#  'pz': 0,
#  'qa': 0,
#  'qb': 0,
#  'qc': 0,
#  'qd': 0,
#  'qe': 0,
#  'qf': 0,
#  'qg': 0,
#  'qh': 0,
#  'qi': 0,
#  'qj': 0,
#  'qk': 0,
#  'ql': 0,
#  'qm': 0,
#  'qn': 0,
#  'qo': 0,
#  'qp': 0,
#  'qq': 0,
#  'qr': 0,
#  'qs': 0,
#  'qt': 0,
#  'qv': 0,
#  'qw': 0,
#  'qx': 0,
#  'qy': 0,
#  'qz': 0,
#  'q ': 0,
#  'rj': 0,
#  'rx': 0,
#  'rz': 0,
#  'sj': 0,
#  'sx': 0,
#  'sz': 0,
#  'tj': 0,
#  'tz': 0,
#  'uj': 0,
#  'uq': 0,
#  'uu': 0,
#  'uv': 0,
#  'ux': 0,
#  'uy': 0,
#  'vb': 0,
#  'vc': 0,
#  'vd': 0,
#  'vf': 0,
#  'vg': 0,
#  'vh': 0,
#  'vj': 0,
#  'vk': 0,
#  'vl': 0,
#  'vm': 0,
#  'vn': 0,
#  'vp': 0,
#  'vq': 0,
#  'vr': 0,
#  'vs': 0,
#  'vt': 0,
#  'vv': 0,
#  'vw': 0,
#  'vx': 0,
#  'vz': 0,
#  'v ': 0,
#  'wb': 0,
#  'wg': 0,
#  'wj': 0,
#  'wu': 0,
#  'wx': 0,
#  'wy': 0,
#  'wz': 0,
#  'xb': 0,
#  'xd': 0,
#  'xf': 0,
#  'xg': 0,
#  'xh': 0,
#  'xj': 0,
#  'xk': 0,
#  'xl': 0,
#  'xm': 0,
#  'xn': 0,
#  'xo': 0,
#  'xq': 0,
#  'xr': 0,
#  'xs': 0,
#  'xu': 0,
#  'xv': 0,
#  'xw': 0,
#  'xx': 0,
#  'xy': 0,
#  'xz': 0,
#  'yj': 0,
#  'yq': 0,
#  'yv': 0,
#  'yx': 0,
#  'yz': 0,
#  'zb': 0,
#  'zc': 0,
#  'zd': 0,
#  'zf': 0,
#  'zg': 0,
#  'zh': 0,
#  'zj': 0,
#  'zk': 0,
#  'zm': 0,
#  'zn': 0,
#  'zo': 0,
#  'zp': 0,
#  'zq': 0,
#  'zr': 0,
#  'zs': 0,
#  'zt': 0,
#  'zu': 0,
#  'zv': 0,
#  'zw': 0,
#  'zx': 0,
#  'z ': 0}

# %% [markdown]
# "e ", "t " and "he" are the most common sequence occurances. This is followed by "th" which i choose to start with because i thought it would be more likely to be at the beginning of a piece of text.

# %%
# Start with "th".
pairs = 'th'
N = 1000
# Do the following N times.
for i in range(1, N-1):
    # Get the weights where the previous two character is the last two characters in pairs.
    wt = threeghts[pairs[-2:]]
    # Turn wt into a list, ordered by chars. 
    wt = [wt[c] for c in chars]
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to twos.
    pairs = pairs + nextc

# %%
pairs
# Out:
# 'the kinargut ortle ordifir hater ittle rem ad the gre it he i win wersweenevet eglens laid to ve denberewits cut oneravebearget he ork and this he hout hutingned the no wicking yould ithad to whavese th sur wor dis way ace pleelfterqueent afris and rempuse sell musiou falmock king she lice maked ithe canxissinsee to sain eve did wor on in min to sawalis thear me ned al alitess alicerselchion guten thown ared nothe gre thandow and ithe youreellonow alice queessold chence it leen said no buten ong alied begamed boull soy a my of sid th abbiten and tre iten the i copyringlorusearks and th onine alis sming hime queente on he a reette wer ever it dogerstiout was oned fought of and ah istersessink a bright couldning wor muse liat wast the it the waill may the king twhe of you pookey prom bes in ind nes not th ifew wil yout fa dat me wrou of ever her he worriank at onay afther saidy asse thorill trunibur oull denber hery th hen ey onevisky gumbily ne she raid by wenbe theas the of knotm whive'

# %% [markdown]
# <h3 style="color: #001a79;">Exercise 2</h3>
#
# <hr style="border-top: 1px solid #001a79;" />
#
# Explain why the log of zero is undefined.

# %% [markdown]
# <img style="border: 1px solid #ff791e; max-width: 400px;" src="https://miro.medium.com/max/1400/1*XiPOOAwlW4oB7-piM2_DxA.jpeg" alt="John Tukey"></img>
# Source: https://medium.com/@kyawsawhtoon/log-transformation-purpose-and-interpretation-9444b4b049c9
#
# Taking the example below we can see the relationship between logs and powers from the image above:

# %%
b = 2
x = 8
y = 3

# %%
import math
y == math.log(x, b)
# Out:
# True

# %%
b ** y == x
# Out:
# True

# %% [markdown]
# For the $log_2({8})$ we are asking how many 2s we need to multiply together to get 8?
#
# The answer is 3

# %%
2 * 2 * 2
# Out:
# 8

# %% [markdown]
# Say the question is how many 2s we need to get 0?

# %% [markdown]
# Our log would be $log_2({0})$ but this gives us an error.

# %%
math.log(0, 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 math.log(0, 2)
#
# ValueError: math domain error

# %% [markdown]
# Why?
#
# There is no way of getting 0 from $2^{x}$ where x is any rational number.

# %%
# Plotting.
import matplotlib.pyplot as plt
# Numerical calculations.
import numpy as np

# A range of possible values.
# We have to avoid 0.0 and 1.0 because of the log.
pos = np.linspace(0.01, 0.99, 100)
neg = np.linspace(-0.99, -0.01, 100)
# Calculate the entropy.
all = np.concatenate((neg, pos), axis=None)
all

log = np.log2(all)
log

# Create the actual plot.
#fig, ax = plt.subplots(figsize=(14, 6))
#ax.plot(all, log, color='#ff791e')

# Label the axes.
#ax.set_xlabel('Probability the bit is 1, not 0.')
#ax.set_ylabel('Entropy');
# Out:
# C:\Users\shane\AppData\Local\Temp\ipykernel_11512\985472439.py:14: RuntimeWarning: invalid value encountered in log2
#   log = np.log2(all)
# array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#        -6.64385619, -5.65116099, -5.06864167, -4.65482731, -4.3336336 ,
#        -4.07108899, -3.84904652, -3.65666397, -3.48694318, -3.33510348,
#        -3.19773366, -3.0723142 , -2.95693128, -2.8500969 , -2.75063128,
#        -2.65758317, -2.57017442, -2.48776034, -2.40980085, -2.33583899,
#        -2.2654847 , -2.19840235, -2.13430109, -2.0729272 , -2.01405804,
#        -1.95749715, -1.90307033, -1.85062238, -1.80001443, -1.75112174,
#        -1.70383185, -1.658043  , -1.61366281, -1.57060721, -1.5287994 ,
#        -1.4881691 , -1.44865178, -1.4101881 , -1.37272333, -1.33620688,
#        -1.30059195, -1.26583508, -1.23189589, -1.19873681, -1.16632276,
#        -1.13462102, -1.10360093, -1.0732338 , -1.04349272, -1.01435238,
#        -0.985789  , -0.95778017, -0.93030478, -0.90334287, -0.87687562,
#        -0.85088519, -0.8253547 , -0.80026818, -0.77561042, -0.75136703,
#        -0.72752431, -0.70406923, -0.68098939, -0.65827296, -0.63590869,
#        -0.61388581, -0.59219407, -0.57082365, -0.54976517, -0.52900966,
#        -0.50854852, -0.48837352, -0.46847676, -0.44885068, -0.429488  ,
#        -0.41038176, -0.39152525, -0.37291202, -0.35453588, -0.33639087,
#        -0.31847123, -0.30077144, -0.28328618, -0.2660103 , -0.24893885,
#        -0.23206704, -0.21539027, -0.19890407, -0.18260414, -0.16648631,
#        -0.15054656, -0.134781  , -0.11918587, -0.10375751, -0.0884924 ,
#        -0.07338713, -0.05843836, -0.04364291, -0.02899765, -0.01449957])
