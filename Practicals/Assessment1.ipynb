# %% [markdown]
# <h3 style="color: #001a79;">Exercise 1</h3>
#
# <hr style="border-top: 1px solid #001a79;" />
#
# Adapt the code from 01-information Jupyer Notebook to generate a 1000 character long string with weights based on the previous two characters.
#
# Firstly, we start by getting the Alice in Wonderland book and storing off www.gutenberg.org, then store it as one big string called **sbook**.

# %%
# Make HTTP requests for internet reqources.
import urllib.request

# For doing (pseudo-)random things in Python.
import random

# The URL of a text version of Alice in Wonderland.
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# Get the book.
book = list(urllib.request.urlopen(book_url))

# Decode the lines and strip line endings.
book = [line.decode('utf-8-sig').strip() for line in book]

# Get the whole book in one big string.
sbook = ''.join(book[26:]).lower()

# %% [markdown]
# Secondly, we create a dictionary to with the weighting system.
#
# The first key is each of the two previous characters possibilites (e.g. "aa", "ba", "cc",............,"y ", "z ", "  ") and it's value is another dictionary. The key of this dictionary is chars (each letter of the alphabet plus space) and its values are the weights of the key.

# %%
# All letters and a space.
chars = 'abcdefghijklmnopqrstuvwxyz '

# Create the weights.
threeghts = {(x + y): {z: sbook.count(x + y + z) for z in chars} for y in chars for x in chars}

# %% [markdown]
# We have to start with two letters, so let's find the most common sequence of two letters.
#
# Using Ian's code, convert into dictionary where the key is the combination of two chars and value is the weights. Order this to find most common.

# %%
# Create the weights.
twoghts = {c: {d: sbook.count(c + d) for d in chars} for c in chars}

counts = []
twos = []
for i in chars:
    for j in chars:
        counts.append(twoghts[i][j])
        twos.append(i + j)
twos = dict(zip(twos, counts))

# https://stackoverflow.com/a/613218
dict(sorted(twos.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'e ': 4843,
#  ' t': 4280,
#  'he': 4011,
#  'th': 3833,
#  ' a': 3304,
#  'd ': 2853,
#  't ': 2818,
#  ' s': 2365,
#  'in': 2264,
#  'er': 2109,
#  's ': 1890,
#  'an': 1776,
#  ' w': 1766,
#  ' i': 1749,
#  'ou': 1704,
#  ' o': 1533,
#  'it': 1492,
#  'n ': 1460,
#  ' h': 1438,
#  'nd': 1411,
#  'at': 1345,
#  're': 1344,
#  'on': 1295,
#  'r ': 1242,
#  'ng': 1232,
#  'o ': 1231,
#  'ha': 1211,
#  'en': 1147,
#  'y ': 1106,
#  'to': 1097,
#  'ed': 1088,
#  'te': 1054,
#  'al': 1018,
#  'as': 944,
#  'li': 941,
#  'or': 937,
#  ' c': 918,
#  ' b': 909,
#  ' m': 900,
#  'se': 896,
#  'sh': 867,
#  'g ': 864,
#  'hi': 860,
#  'ar': 846,
#  ' d': 843,
#  'ea': 835,
#  'f ': 831,
#  'le': 814,
#  'ce': 796,
#  ' f': 784,
#  've': 759,
#  'ai': 752,
#  'of': 749,
#  'll': 748,
#  'ut': 748,
#  ' l': 738,
#  'id': 730,
#  'es': 722,
#  'is': 715,
#  'st': 712,
#  'ic': 689,
#  'sa': 668,
#  'a ': 660,
#  'be': 651,
#  'me': 649,
#  'ti': 636,
#  ' p': 622,
#  'ho': 604,
#  ' g': 601,
#  'wa': 600,
#  'ne': 597,
#  'no': 596,
#  'yo': 586,
#  'nt': 577,
#  'h ': 571,
#  'ow': 566,
#  'l ': 562,
#  'ee': 553,
#  'ro': 543,
#  ' n': 533,
#  'ur': 532,
#  'wh': 530,
#  'de': 525,
#  ' r': 522,
#  'ch': 517,
#  ' y': 505,
#  'el': 501,
#  'ot': 499,
#  'do': 487,
#  'ad': 482,
#  'us': 471,
#  'ly': 468,
#  'oo': 465,
#  'co': 455,
#  'ri': 453,
#  'so': 451,
#  'wi': 444,
#  'fo': 423,
#  ' e': 413,
#  'ry': 393,
#  'et': 386,
#  'ma': 384,
#  'ke': 377,
#  'tt': 376,
#  'rs': 374,
#  'i ': 369,
#  'la': 366,
#  'we': 365,
#  'ra': 361,
#  'u ': 357,
#  'ul': 355,
#  'wo': 354,
#  'ca': 353,
#  'lo': 348,
#  'ld': 346,
#  'il': 345,
#  'gh': 339,
#  'ta': 339,
#  'mo': 338,
#  'om': 336,
#  'di': 331,
#  'pe': 331,
#  'ec': 329,
#  'k ': 327,
#  'un': 327,
#  'em': 324,
#  'ge': 314,
#  'rt': 300,
#  'io': 299,
#  'si': 299,
#  'ay': 294,
#  'tl': 293,
#  ' u': 293,
#  'm ': 281,
#  'gr': 252,
#  'ht': 250,
#  ' k': 245,
#  'ab': 243,
#  'im': 243,
#  'ss': 243,
#  'tr': 242,
#  'bu': 239,
#  'ig': 237,
#  'ct': 236,
#  'ga': 234,
#  'pr': 233,
#  'w ': 231,
#  'bo': 228,
#  'ir': 228,
#  ' v': 225,
#  'ey': 224,
#  'ie': 223,
#  'ok': 223,
#  'pl': 222,
#  'qu': 222,
#  'up': 222,
#  'ni': 221,
#  'ag': 220,
#  'nc': 215,
#  'ki': 213,
#  'tu': 210,
#  'ac': 208,
#  'ev': 205,
#  'ns': 205,
#  'am': 202,
#  'go': 202,
#  'mi': 201,
#  'ol': 200,
#  'ts': 200,
#  'po': 199,
#  'if': 193,
#  'fi': 190,
#  'ep': 188,
#  'uc': 186,
#  'rd': 185,
#  'ck': 182,
#  'fe': 179,
#  'av': 178,
#  'rg': 175,
#  'su': 175,
#  'ug': 175,
#  '  ': 173,
#  ' q': 171,
#  'ue': 169,
#  'op': 160,
#  'p ': 160,
#  'pa': 159,
#  'rk': 155,
#  'os': 154,
#  'ap': 147,
#  'lf': 147,
#  'wn': 147,
#  'eg': 145,
#  'pi': 144,
#  'na': 141,
#  'gu': 140,
#  'kn': 139,
#  'ny': 138,
#  'da': 137,
#  'mu': 136,
#  'rm': 136,
#  'ff': 132,
#  'ak': 131,
#  'oi': 130,
#  'pp': 130,
#  'fu': 126,
#  'cr': 125,
#  'bl': 124,
#  'ex': 123,
#  'bi': 122,
#  'ef': 119,
#  'fa': 116,
#  'nk': 116,
#  'fr': 114,
#  'cu': 113,
#  'oc': 113,
#  'ei': 112,
#  'od': 110,
#  'ov': 110,
#  ' j': 107,
#  'je': 106,
#  'iv': 105,
#  'mp': 105,
#  'ds': 104,
#  'ye': 104,
#  'sp': 103,
#  'ju': 102,
#  'by': 101,
#  'nl': 100,
#  'nb': 99,
#  'ik': 97,
#  'rn': 97,
#  'rr': 97,
#  'aw': 96,
#  'vi': 96,
#  'gi': 95,
#  'dr': 94,
#  'tw': 93,
#  'ui': 90,
#  'hr': 89,
#  'ft': 88,
#  'cl': 87,
#  'pt': 86,
#  'oj': 85,
#  'ru': 85,
#  'tm': 84,
#  'ba': 82,
#  'ph': 82,
#  'ty': 82,
#  'au': 80,
#  'rc': 80,
#  'rp': 80,
#  'ew': 79,
#  'pu': 79,
#  'dd': 75,
#  'du': 70,
#  'sl': 70,
#  'vo': 70,
#  'lt': 69,
#  'af': 68,
#  'bb': 68,
#  'my': 68,
#  'gs': 67,
#  'yi': 67,
#  'dl': 65,
#  'ud': 65,
#  'gl': 64,
#  'mb': 64,
#  'sn': 63,
#  'br': 62,
#  'ks': 62,
#  'nu': 62,
#  'dn': 61,
#  'yp': 61,
#  'lk': 60,
#  'um': 60,
#  'ia': 59,
#  'hu': 58,
#  'nn': 57,
#  'oh': 57,
#  'rl': 57,
#  'ci': 56,
#  'eb': 55,
#  'eh': 54,
#  'ib': 53,
#  'dy': 52,
#  'ls': 51,
#  'oe': 51,
#  'py': 50,
#  'sc': 49,
#  'ys': 49,
#  'ob': 48,
#  'sk': 48,
#  'tc': 48,
#  'hy': 47,
#  'ms': 47,
#  'yt': 47,
#  'eo': 45,
#  'og': 42,
#  'sw': 42,
#  'xt': 42,
#  'wr': 38,
#  'cc': 36,
#  'fl': 36,
#  'lu': 36,
#  'bs': 35,
#  'c ': 35,
#  'dt': 35,
#  'ub': 35,
#  'dg': 34,
#  'ya': 34,
#  'nf': 33,
#  'ps': 32,
#  'wl': 32,
#  'ze': 32,
#  'ws': 31,
#  'xp': 31,
#  'ah': 30,
#  'sm': 29,
#  'va': 29,
#  'ua': 28,
#  'iz': 27,
#  'oa': 27,
#  'xe': 27,
#  'xi': 27,
#  'ip': 25,
#  'rh': 25,
#  'kl': 23,
#  'yr': 23,
#  'nv': 22,
#  'oy': 22,
#  'dv': 21,
#  'ek': 19,
#  'eq': 19,
#  'mm': 19,
#  'mn': 19,
#  'rf': 19,
#  'tg': 19,
#  'gg': 18,
#  'gt': 18,
#  'xc': 18,
#  'jo': 17,
#  'lw': 17,
#  'nx': 17,
#  'tf': 17,
#  'lp': 16,
#  'df': 15,
#  'ww': 15,
#  'x ': 15,
#  'ez': 14,
#  'tn': 14,
#  'uz': 14,
#  'zl': 14,
#  'zz': 14,
#  'bt': 13,
#  'gn': 13,
#  'lv': 13,
#  'rw': 13,
#  'yb': 13,
#  'yc': 13,
#  'aj': 12,
#  'ax': 12,
#  'db': 12,
#  'dw': 12,
#  'ii': 12,
#  'nw': 12,
#  'oq': 12,
#  'xa': 12,
#  'dh': 11,
#  'ix': 11,
#  'ka': 11,
#  'lc': 11,
#  'ox': 11,
#  'rv': 11,
#  'wd': 11,
#  'zi': 11,
#  'mf': 10,
#  'sy': 10,
#  'yd': 10,
#  'ym': 10,
#  'iu': 9,
#  'ky': 9,
#  'lm': 9,
#  'td': 9,
#  'bj': 8,
#  'cy': 8,
#  'eu': 8,
#  'hs': 8,
#  'kt': 8,
#  'lr': 8,
#  'nh': 8,
#  'yw': 8,
#  'fy': 7,
#  'np': 7,
#  'sg': 7,
#  'sq': 7,
#  'za': 7,
#  'dp': 6,
#  'hm': 6,
#  'ja': 6,
#  'nq': 6,
#  'yl': 6,
#  ' x': 6,
#  'az': 5,
#  'gf': 5,
#  'hb': 5,
#  'lb': 5,
#  'mt': 5,
#  'sf': 5,
#  'uf': 5,
#  'uk': 5,
#  'wf': 5,
#  'wt': 5,
#  'dc': 4,
#  'ej': 4,
#  'gw': 4,
#  'hd': 4,
#  'hl': 4,
#  'iw': 4,
#  'lh': 4,
#  'ml': 4,
#  'sr': 4,
#  'tb': 4,
#  'yf': 4,
#  'yh': 4,
#  'yn': 4,
#  'ao': 3,
#  'b ': 3,
#  'dm': 3,
#  'fc': 3,
#  'fs': 3,
#  'hc': 3,
#  'hf': 3,
#  'hn': 3,
#  'lg': 3,
#  'mw': 3,
#  'nj': 3,
#  'nr': 3,
#  'pb': 3,
#  'pm': 3,
#  'rb': 3,
#  'rq': 3,
#  'sd': 3,
#  'tk': 3,
#  'tp': 3,
#  'uo': 3,
#  'vy': 3,
#  'yg': 3,
#  'yu': 3,
#  'yy': 3,
#  'fm': 2,
#  'gc': 2,
#  'gp': 2,
#  'gy': 2,
#  'hw': 2,
#  'ko': 2,
#  'ku': 2,
#  'nm': 2,
#  'oz': 2,
#  'pd': 2,
#  'pg': 2,
#  'sv': 2,
#  'tq': 2,
#  'tv': 2,
#  'yk': 2,
#  'zy': 2,
#  ' z': 2,
#  'ae': 1,
#  'bd': 1,
#  'bm': 1,
#  'cs': 1,
#  'dj': 1,
#  'dk': 1,
#  'fd': 1,
#  'fg': 1,
#  'fh': 1,
#  'fn': 1,
#  'fp': 1,
#  'fv': 1,
#  'gb': 1,
#  'gd': 1,
#  'gv': 1,
#  'gz': 1,
#  'hg': 1,
#  'hh': 1,
#  'hj': 1,
#  'hp': 1,
#  'ih': 1,
#  'jc': 1,
#  'kf': 1,
#  'kr': 1,
#  'kw': 1,
#  'mc': 1,
#  'mg': 1,
#  'mh': 1,
#  'pw': 1,
#  'sb': 1,
#  'tx': 1,
#  'uh': 1,
#  'uw': 1,
#  'vu': 1,
#  'wc': 1,
#  'wk': 1,
#  'wm': 1,
#  'wp': 1,
#  'wq': 1,
#  'wv': 1,
#  'aa': 0,
#  'aq': 0,
#  'bc': 0,
#  'bf': 0,
#  'bg': 0,
#  'bh': 0,
#  'bk': 0,
#  'bn': 0,
#  'bp': 0,
#  'bq': 0,
#  'bv': 0,
#  'bw': 0,
#  'bx': 0,
#  'bz': 0,
#  'cb': 0,
#  'cd': 0,
#  'cf': 0,
#  'cg': 0,
#  'cj': 0,
#  'cm': 0,
#  'cn': 0,
#  'cp': 0,
#  'cq': 0,
#  'cv': 0,
#  'cw': 0,
#  'cx': 0,
#  'cz': 0,
#  'dq': 0,
#  'dx': 0,
#  'dz': 0,
#  'fb': 0,
#  'fj': 0,
#  'fk': 0,
#  'fq': 0,
#  'fw': 0,
#  'fx': 0,
#  'fz': 0,
#  'gj': 0,
#  'gk': 0,
#  'gm': 0,
#  'gq': 0,
#  'gx': 0,
#  'hk': 0,
#  'hq': 0,
#  'hv': 0,
#  'hx': 0,
#  'hz': 0,
#  'ij': 0,
#  'iq': 0,
#  'iy': 0,
#  'jb': 0,
#  'jd': 0,
#  'jf': 0,
#  'jg': 0,
#  'jh': 0,
#  'ji': 0,
#  'jj': 0,
#  'jk': 0,
#  'jl': 0,
#  'jm': 0,
#  'jn': 0,
#  'jp': 0,
#  'jq': 0,
#  'jr': 0,
#  'js': 0,
#  'jt': 0,
#  'jv': 0,
#  'jw': 0,
#  'jx': 0,
#  'jy': 0,
#  'jz': 0,
#  'j ': 0,
#  'kb': 0,
#  'kc': 0,
#  'kd': 0,
#  'kg': 0,
#  'kh': 0,
#  'kj': 0,
#  'kk': 0,
#  'km': 0,
#  'kp': 0,
#  'kq': 0,
#  'kv': 0,
#  'kx': 0,
#  'kz': 0,
#  'lj': 0,
#  'ln': 0,
#  'lq': 0,
#  'lx': 0,
#  'lz': 0,
#  'md': 0,
#  'mj': 0,
#  'mk': 0,
#  'mq': 0,
#  'mr': 0,
#  'mv': 0,
#  'mx': 0,
#  'mz': 0,
#  'nz': 0,
#  'pc': 0,
#  'pf': 0,
#  'pj': 0,
#  'pk': 0,
#  'pn': 0,
#  'pq': 0,
#  'pv': 0,
#  'px': 0,
#  'pz': 0,
#  'qa': 0,
#  'qb': 0,
#  'qc': 0,
#  'qd': 0,
#  'qe': 0,
#  'qf': 0,
#  'qg': 0,
#  'qh': 0,
#  'qi': 0,
#  'qj': 0,
#  'qk': 0,
#  'ql': 0,
#  'qm': 0,
#  'qn': 0,
#  'qo': 0,
#  'qp': 0,
#  'qq': 0,
#  'qr': 0,
#  'qs': 0,
#  'qt': 0,
#  'qv': 0,
#  'qw': 0,
#  'qx': 0,
#  'qy': 0,
#  'qz': 0,
#  'q ': 0,
#  'rj': 0,
#  'rx': 0,
#  'rz': 0,
#  'sj': 0,
#  'sx': 0,
#  'sz': 0,
#  'tj': 0,
#  'tz': 0,
#  'uj': 0,
#  'uq': 0,
#  'uu': 0,
#  'uv': 0,
#  'ux': 0,
#  'uy': 0,
#  'vb': 0,
#  'vc': 0,
#  'vd': 0,
#  'vf': 0,
#  'vg': 0,
#  'vh': 0,
#  'vj': 0,
#  'vk': 0,
#  'vl': 0,
#  'vm': 0,
#  'vn': 0,
#  'vp': 0,
#  'vq': 0,
#  'vr': 0,
#  'vs': 0,
#  'vt': 0,
#  'vv': 0,
#  'vw': 0,
#  'vx': 0,
#  'vz': 0,
#  'v ': 0,
#  'wb': 0,
#  'wg': 0,
#  'wj': 0,
#  'wu': 0,
#  'wx': 0,
#  'wy': 0,
#  'wz': 0,
#  'xb': 0,
#  'xd': 0,
#  'xf': 0,
#  'xg': 0,
#  'xh': 0,
#  'xj': 0,
#  'xk': 0,
#  'xl': 0,
#  'xm': 0,
#  'xn': 0,
#  'xo': 0,
#  'xq': 0,
#  'xr': 0,
#  'xs': 0,
#  'xu': 0,
#  'xv': 0,
#  'xw': 0,
#  'xx': 0,
#  'xy': 0,
#  'xz': 0,
#  'yj': 0,
#  'yq': 0,
#  'yv': 0,
#  'yx': 0,
#  'yz': 0,
#  'zb': 0,
#  'zc': 0,
#  'zd': 0,
#  'zf': 0,
#  'zg': 0,
#  'zh': 0,
#  'zj': 0,
#  'zk': 0,
#  'zm': 0,
#  'zn': 0,
#  'zo': 0,
#  'zp': 0,
#  'zq': 0,
#  'zr': 0,
#  'zs': 0,
#  'zt': 0,
#  'zu': 0,
#  'zv': 0,
#  'zw': 0,
#  'zx': 0,
#  'z ': 0}

# %% [markdown]
# "e ", "t " and "he" are the most common sequence occurances. This is followed by "th" which i choose to start with because i though it would be more likely to be at the beginning of a piece of text.

# %%
# Start with "th".
pairs = 'th'
N = 1000
# Do the following N times.
for i in range(1, N-1):
    # Get the weights where the previous two character is the last two characters in pairs.
    wt = threeghts[pairs[-2:]]
    # Turn wt into a list, ordered by chars. 
    wt = [wt[c] for c in chars]
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to twos.
    pairs = pairs + nextc

# %%
pairs
# Out:
# 'the licedgethe theleas uslad witerming oread the to procirsof it ond ordandbeginkess feeks in manown you ards the laid theyeseelyphone drojechents one is anythand quirtand ely aliked they it ittel sitermanscany are ext ou knery goicess hat it ally ove said itter catiect uself ke alobtfuldno and ved he anall thes in ber it it and thatif i donly to sude offeen thesky she comenly rogere ful take hattistremblicut he bothe or and the rall peand their san prot of wit severturtleas aftelf the puterse foremnly thade if thating havere to caulke bour hey nottleader croul put the soseve the of muchat fluststran a land i dodeadnou kne crabothe jumpletuterger post berls th his twousting myest haper begainkin forks sher inthe a no up and and whinks quit sit theref to sup mid tat it upillyclaid hing on very yous a but overe ofvoichere conce me weversed to sis ever fir atted he quit is lit itioniter formew a veryphou mystif youssome tre ciamed tabbee cold to ischown anderemen befir sines ahicess earg '
